# %% [markdown]
# ## Importing The Packages

# %%
import numpy as np 
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Reading The Dataset

# %%
df=pd.read_csv("loan_prediction.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#       ApplicantIncome  CoApplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                5849                0.0         NaN             360.0
# 1                4583             1508.0       128.0             360.0
# 2                3000                0.0        66.0             360.0
# 3                2583             2358.0       120.0             360.0
# 4                6000                0.0       141.0             360.0
# ..                ...                ...         ...               ...
# 609              2900                0.0        71.0             360.0
# 610              4106                0.0        40.0             180.0
# 611              8072              240.0       253.0             360.0
# 612              7583                0.0       187.0             360.0
# 613              4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#       ApplicantIncome  CoApplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                5849                0.0         NaN             360.0
# 1                4583             1508.0       128.0             360.0
# 2                3000                0.0        66.0             360.0
# 3                2583             2358.0       120.0             360.0
# 4                6000                0.0       141.0             360.0
# ..                ...                ...         ...               ...
# 609              2900                0.0        71.0             360.0
# 610              4106                0.0        40.0             180.0
# 611              8072              240.0       253.0             360.0
# 612              7583                0.0       187.0             360.0
# 613              4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 0               1.0         Urban           Y
# 1               1.0         Rural           N
# 2               1.0         Urban           Y
# 3               1.0         Urban           Y
# 4               1.0         Urban           Y
# ..              ...           ...         ...
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N
#
# [614 rows x 13 columns]

# %%
df.shape
# Out:
# (614, 13)

# %% [markdown]
# ## Handling The Missing Values

# %%
#checking the null values
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
#  ApplicantIncome      0
# CoApplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# ## Treating The Null Value

# %%
# We will fill the missing values in numeric data type using the mean value of that particular column and categorical data type using the most repeated value

# %%
numerical_features = df.select_dtypes(include = [np.number]).columns
categorical_features = df.select_dtypes(include = [np.object]).columns

# %%
numerical_features
# Out:
# Index([' ApplicantIncome', 'CoApplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %%
categorical_features
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])

# %%
#replace + with non value 
df['Dependents'] = df['Dependents'].str.replace('+','')

# %%
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].mode()[0])
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0])
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mode()[0])

# %%
#checking the null values now
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
#  ApplicantIncome     0
# CoApplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
# The Null Values has been retreated now

# %% [markdown]
# ## Handling Categorical Values

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].replace({'Male':1,'Female':0},inplace=True)

# %%
df['Married'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Married'].replace({'Yes':1,'No':0},inplace=True)

# %%
df['Dependents'].unique()
# Out:
# array(['0', '1', '2', '3'], dtype=object)

# %%
df['Dependents'].replace({'0':0,'1':1,'2':2,'3':3},inplace=True)

# %%
df['Self_Employed'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['Self_Employed'].replace({'Yes':1,'No':0},inplace=True)

# %%
df['Property_Area'].unique()
# Out:
# array(['Urban', 'Rural', 'Semiurban'], dtype=object)

# %%
df['Property_Area'].replace({'Urban':2,'Rural':0,'Semiurban':1},inplace=True)

# %%
df['Loan_Status'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df['Loan_Status'].replace({'Y':1,'N':0},inplace=True)

# %%
df['Education'].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %%
df['Education'].replace({'Graduate':1,'Not Graduate':0},inplace=True)

# %%
df['CoApplicantIncome']=df['CoApplicantIncome'].astype("int64")
df['LoanAmount']=df['LoanAmount'].astype("int64")
df['Loan_Amount_Term']=df['Loan_Amount_Term'].astype("int64")
df['Credit_History']=df['Credit_History'].astype("int64")

# %%
# dummy columns are created for the categories in Loan_ID
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Loan_ID'] = le.fit_transform(df.Loan_ID)

# %%
df.head()
# Out:
#    Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0        0       1        0           0          1              0
# 1        1       1        1           1          1              0
# 2        2       1        1           0          1              1
# 3        3       1        1           0          0              0
# 4        4       1        0           0          1              0
#
#     ApplicantIncome  CoApplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              5849                  0         120               360
# 1              4583               1508         128               360
# 2              3000                  0          66               360
# 3              2583               2358         120               360
# 4              6000                  0         141               360
#
#    Credit_History  Property_Area  Loan_Status
# 0               1              2            1
# 1               1              0            0
# 2               1              2            1
# 3               1              2            1
# 4               1              2            1

# %%
df.tail()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 609      609       0        0           0          1              0
# 610      610       1        1           3          1              0
# 611      611       1        1           1          1              0
# 612      612       1        1           2          1              0
# 613      613       0        0           0          1              1
#
#       ApplicantIncome  CoApplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609              2900                  0          71               360
# 610              4106                  0          40               180
# 611              8072                240         253               360
# 612              7583                  0         187               360
# 613              4583                  0         133               360
#
#      Credit_History  Property_Area  Loan_Status
# 609               1              0            1
# 610               1              0            1
# 611               1              2            1
# 612               1              2            1
# 613               0              1            0

# %% [markdown]
# # Balancing The Dataset

# %%
from imblearn.combine import SMOTETomek

# %%
smote = SMOTETomek(0.90)

# %%
#dividing the dataset into dependent and independent y and x respectively

y = df['Loan_Status']
x = df.drop(columns=['Loan_Status'],axis=1)

# %%
#creating the new x and y for balance data
x_bal,y_bal = smote.fit_resample(x,y)

# %%
#printing the value before and after balancing 
print(y.value_counts())
print(y_bal.value_counts())
# Out:
# 1    422
# 0    192
# Name: Loan_Status, dtype: int64
# 1    360
# 0    317
# Name: Loan_Status, dtype: int64

# %% [markdown]
# ## Scaling The Data

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
x_bal = sc.fit_transform(x_bal)

# %%
x_bal = pd.DataFrame(x_bal)

# %%
x_bal.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -1.764089  0.533507 -1.194372 -0.710283  0.604086 -0.314684  0.081240
# 1 -1.758280  0.533507  0.837260  0.339633  0.604086 -0.314684 -0.131588
# 2 -1.752472  0.533507  0.837260 -0.710283  0.604086  3.177792 -0.397707
# 3 -1.746664  0.533507  0.837260 -0.710283 -1.655395 -0.314684 -0.467809
# 4 -1.740856  0.533507 -1.194372 -0.710283  0.604086 -0.314684  0.106625
#
#          7         8         9         10        11
# 0 -0.505300 -0.292786  0.273236  0.579056  1.341256
# 1  0.001887 -0.189783  0.273236  0.579056 -1.223801
# 2 -0.505300 -0.988057  0.273236  0.579056  1.341256
# 3  0.287769 -0.292786  0.273236  0.579056  1.341256
# 4 -0.505300 -0.022404  0.273236  0.579056  1.341256

# %% [markdown]
# # Splitting Data Into Train And Test

# %%
# splitting the data into training and testing set

from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x_bal, y_bal, test_size = 0.33, random_state = 42)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (453, 12)
# (453,)
# (224, 12)
# (224,)

# %%
x_train
# Out:
#            0         1         2         3         4         5         6   \
# 291  0.216527 -1.874389 -1.194372 -0.710283  0.604086 -0.314684 -0.502272
# 221 -0.259750  0.533507  0.837260  2.439466 -1.655395 -0.314684 -0.073085
# 616  0.483707  0.533507 -1.194372 -0.710283  0.604086  3.177792  0.819415
# 662 -1.409785  0.533507 -1.194372  1.389550 -1.655395 -0.314684 -0.105867
# 319  0.431433  0.533507 -1.194372 -0.710283  0.604086 -0.314684 -0.386107
# ..        ...       ...       ...       ...       ...       ...       ...
# 71  -1.282003  0.533507  0.837260 -0.710283  0.604086 -0.314684  0.106625
# 106 -1.049673  0.533507  0.837260  1.389550  0.604086 -0.314684 -0.404936
# 270  0.071321  0.533507  0.837260  1.389550  0.604086 -0.314684 -0.277172
# 435  1.291055  0.533507  0.837260 -0.710283  0.604086 -0.314684 -0.267421
# 102 -1.072906 -1.874389 -1.194372 -0.710283  0.604086 -0.314684  0.847657
#
#            7         8         9         10        11
# 291 -0.505300 -1.245564  0.273236  0.579056 -1.223801
# 221 -0.505300 -0.189783  0.273236  0.579056  0.058727
# 616 -0.505300  0.389608  0.273236 -1.726949  0.058727
# 662 -0.505300 -0.576045  0.273236 -1.726949 -1.223801
# 319 -0.505300 -0.923680  2.090481  0.579056  1.341256
# ..        ...       ...       ...       ...       ...
# 71   0.251445  1.574143  0.273236  0.579056  0.058727
# 106 -0.505300 -0.794926  0.273236  0.579056  0.058727
# 270 -0.505300 -0.292786  0.273236  0.579056  0.058727
# 435 -0.505300 -0.421540  0.273236  0.579056  0.058727
# 102 -0.505300  1.496891  0.273236  0.579056  1.341256
#
# [453 rows x 12 columns]

# %%
x_test
# Out:
#            0         1         2         3         4         5         6   \
# 646 -0.050653 -1.874389  0.837260  0.339633  0.604086 -0.314684 -0.133437
# 336  0.565022  0.533507 -1.194372 -0.710283 -1.655395 -0.314684 -0.438894
# 63  -1.340086  0.533507  0.837260  2.439466 -1.655395 -0.314684 -0.102673
# 367  0.785736 -1.874389  0.837260 -0.710283 -1.655395  3.177792  0.298608
# 101 -1.078714  0.533507  0.837260 -0.710283  0.604086 -0.314684  0.034001
# ..        ...       ...       ...       ...       ...       ...       ...
# 33  -1.537567  0.533507 -1.194372 -0.710283 -1.655395 -0.314684 -0.271960
# 227 -0.219092  0.533507  0.837260  1.389550  0.604086 -0.314684 -0.110574
# 480  1.610509  0.533507 -1.194372 -0.710283  0.604086 -0.314684 -0.593388
# 9   -1.711814  0.533507  0.837260  0.339633  0.604086 -0.314684  1.256671
# 22  -1.613074  0.533507  0.837260 -0.710283  0.604086 -0.314684 -0.431497
#
#             7         8         9         10        11
# 646  -0.505300 -0.498792  0.273236  0.579056  0.058727
# 336  -0.505300 -1.000932 -0.635387  0.579056 -1.223801
# 63   -0.505300 -0.614671  0.273236 -1.726949  0.058727
# 367  -0.505300 -0.061030  0.273236  0.579056 -1.223801
# 101   0.215121  0.415359  0.273236  0.579056 -1.223801
# ..         ...       ...       ...       ...       ...
# 33    0.055700 -0.421540  0.273236  0.579056  0.058727
# 227  -0.038809  0.093475  0.273236  0.579056  0.058727
# 480  10.875129 -0.679048  0.273236  0.579056  1.341256
# 9     3.183578  2.655674  0.273236  0.579056  0.058727
# 22    0.252454 -0.267036  0.273236  0.579056  0.058727
#
# [224 rows x 12 columns]

# %%
y_train
# Out:
# 291    0
# 221    0
# 616    0
# 662    0
# 319    0
#       ..
# 71     0
# 106    1
# 270    1
# 435    1
# 102    1
# Name: Loan_Status, Length: 453, dtype: int64
